# %%
import numpy as np
from scipy.io.wavfile import read
from scipy import signal, arange
from scipy.signal import hilbert, find_peaks_cwt
import matplotlib.pyplot as plt
import matplotlib.axes as matax
import matplotlib.mlab as mlab
import sys
from math import exp
import operator

# %%
def dirDist(x):
    return np.sqrt(x**2 + (oceanDepth - auvDepth) ** 2)

# %%
def refDist(x):
    return np.sqrt(oceanDepth**2  + ref1helper(x)**2) + np.sqrt(auvDepth**2 + (x-ref1helper(x))**2)

# %%
def ref1helper(x):
    return oceanDepth*x/(oceanDepth + auvDepth)

# %%
def ref2Dist(x):
    return 2 * np.sqrt(oceanDepth**2 + ref2helper(x)**2) + np.sqrt((oceanDepth-auvDepth)**2 + (x-2*ref2helper(x))**2)

# %%
def ref2helper(x):
    return oceanDepth*x/(3*oceanDepth-auvDepth)

# %%
def firTimeDist(x):
    return refDist(x) - dirDist(x)

# %%
def secTimeDist(x):
    return ref2Dist(x) - dirDist(x)

# %%
oceanDepth = 50
auvDepth = 20

# %%
firstArrival = []
secondArrival = []
xdist = 200
for i in range(xdist):
    firstArrival.append(firTimeDist(i));
    secondArrival.append(secTimeDist(i));

# %%
plt.figure(figsize=(20,5))
plt.plot(arange(xdist), firstArrival, label="first");
plt.xlabel("hor. dist");
plt.ylabel("dist diff");
plt.plot(arange(xdist), secondArrival, label="second");
plt.legend();
plt.show()

# %%
# Out:
# [(0, 40.0, 100.0),
#  (1, 39.990480453141288, 99.987184057344791),
#  (2, 39.961972843300572, 99.948790948414228),
#  (3, 39.914629359050764, 99.884983913922298),
#  (4, 39.848700670989302, 99.79603200226974),
#  (5, 39.764531586599901, 99.682305661085763),
#  (6, 39.662555199444476, 99.544270798422815),
#  (7, 39.543285746347507, 99.382481527907558),
#  (8, 39.407310422714104, 99.197571848799427),
#  (9, 39.255280427643903, 98.990246533587225),
#  (10, 39.087901516970959, 98.761271502369169),
#  (11, 38.905924334886578, 98.511463955922395),
#  (12, 38.710134775451792, 98.241682520133693),
#  (13, 38.501344596766629, 97.952817626027937),
#  (14, 38.280382475805297, 97.645782314955525),
#  (15, 38.048085653884918, 97.321503620527182),
#  (16, 37.805292284064961, 96.980914640263535),
#  (17, 37.552834554674682, 96.624947372859594),
#  (18, 37.291532629298807, 96.254526363111552),
#  (19, 37.022189414024957, 95.870563167025381),
#  (20, 36.745586138165294, 95.473951625019168),
#  (21, 36.462478715172743, 95.065563911604954),
#  (22, 36.173594835900012, 94.646247315319528),
#  (23, 35.879631736282974, 94.216821692548152),
#  (24, 35.581254575402909, 93.778077532688826),
#  (25, 35.279095357059255, 93.33077456920401),
#  (26, 34.973752327819469, 92.875640870853985),
#  (27, 34.665789786389645, 92.413372349191974),
#  (28, 34.355738242516672, 91.944632621667921),
#  (29, 34.04409486800833, 91.470053173964246),
#  (30, 33.731324187446234, 90.990233770070489),
#  (31, 33.417858961446832, 90.505743063779846),
#  (32, 33.104101220652808, 90.017119370513868),
#  (33, 32.790423413827902, 89.524871563469134),
#  (34, 32.477169638356337, 89.029480062908078),
#  (35, 32.164656926028208, 88.531397891898166),
