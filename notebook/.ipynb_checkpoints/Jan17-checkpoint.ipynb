# %%
import numpy as np
from scipy.io.wavfile import read
from scipy import signal
import matplotlib.pyplot as plt
import matplotlib.axes as matax
import sys

# %%
#samplingFrequency
sampFreq, sound = read('wav1.wav');
print(sampFreq, len(sound), min(sound), max(sound));
# Out:
# 65501 78601546 -1275 1254

# %%
#seconds 
initTime = 15;
duration = 5;

# %%
start = sampFreq * initTime;
end = start + sampFreq * duration;
s1 = sound[start:end];
print(len(s1))
# Out:
# 327505

# %%
timeArray = np.arange(0, end-start, 1)
timeArray = timeArray / sampFreq
#timeArray = timeArray

# %%
fig = plt.figure()
#fig, axes = plt.subplots(nrows=2, ncols=1)
ax1 = fig.add_axes( [0.12, 0.55, 0.75, 0.4] )
ax2 = fig.add_axes( [0.12, 0.1, 0.75, 0.4] )
ax3 = fig.add_axes( [0.88, 0.1, 0.02, 0.4] )
    
#--- Figure 1. ---#
ax1.plot(timeArray, s1)
ax1.set_ylabel('Amplitude')
ax1.set_xlim(0, duration)
ax1.margins(x=0)
#--- Figure 2. ---#
f, t, Sxx = signal.spectrogram(s1, sampFreq, nperseg=256)
im = ax2.pcolormesh(t, f/1000, np.log(Sxx), cmap='jet' )

tendev = np.std(s1) * 10
a = s1 > tendev
#for values in s2:
#    if(values < tendev)
#        values = 0
#print(tendev)
ax1.scatter(timeArray[a],s1[a])

ax2.set_ylabel('Frequency [kHz]')
ax2.set_ylim(0,20)
ax2.set_xlim(0, duration);
ax2.set_xlabel('Time (s)')
ax2.margins(x=0)
im.set_clim(-10, 0)

mappable = im
cb = plt.colorbar(mappable = mappable, cax = ax3)
cb.set_label('db/Hz')

# %%
Sxx_db = 20*np.log10(Sxx)

# %%
tendev = np.std(s1) * 10
a = s1 > tendev
#for values in s2:
#    if(values < tendev)
#        values = 0
print(tendev)
# Out:
# 242.529107793

# %%
timeArray[a]
snaps = [];

current = timeArray[a][0]
snaps.append(current)

for time in timeArray[a] {
    
    if (time > current + 0.01 ) {
        snaps.append(time);
        current = time;
    }
}
# Out:
# array([ 1.4555503 ,  1.92772629,  1.9278637 ,  1.92787896,  1.92789423,
#         1.92891712,  3.75105724,  3.75114884,  3.75124044,  3.75125571,
#         3.75133204,  3.75134731,  3.75142364,  3.75143891,  3.75151524,
#         3.75153051,  3.75160685,  3.75162211,  3.75169845,  3.75171371,
#         3.75179005,  3.75180532,  3.75188165,  3.75195799,  3.75197325,
#         3.75204959,  3.75206485,  3.75212592,  3.75214119,  3.75215646,
#         3.75221752,  3.75223279,  3.75230913,  3.75232439,  3.75238546,
#         3.75240073,  3.75241599,  3.75247706,  3.75249233,  3.75256866,
#         3.75258393,  3.752645  ,  3.75266026,  3.7527366 ,  3.75281293,
#         3.7528282 ,  3.75290454,  3.75298087,  3.75305721,  3.75313354,
#         3.75314881,  3.75320987,  3.75322514,  3.75328621,  3.75330148,
#         3.75336254,  3.75337781,  3.75339308,  3.75345415,  3.75346941,
#         3.75353048,  3.75354575,  3.75360682,  3.75362208,  3.75368315,
#         3.75369842,  3.75377475,  3.75379002,  3.75385109,  3.75386635,
#         3.75392742,  3.75394269,  3.75400376,  3.75401902,  3.75406482,
#         3.75414116,  3.75421749,  3.75429383,  3.75437016,  3.75450756,
#         3.7545839 ,  3.75464497,  3.75466023,  3.7547213 ,  3.75473657,
#         3.75479764,  3.7548129 ,  3.75487397,  3.75488924,  3.75495031,
#         3.75501137,  3.75502664,  3.75508771,  3.75510298,  3.75516404,
#         3.75517931,  3.75524038,  3.75530145,  3.75531671,  3.75537778,
#         3.75539305,  3.75545412,  3.75551518,  3.75553045,  3.75559152,
#         3.75560678,  3.75566785,  3.75574419,  4.88604754])

# %%
timeArray[a][0]
# Out:
# 1.4555502969420315

# %%
plt.show();

# %%
def avgfreq(f, start, end):
    freq = f[start:end];
    print(freq);

# %%
def startOfPing(f):
    print(max(f))

# %%
print(len(f), len(t), len(Sxx))
#diff of f is nperseg.

# %%
max(f)

# %%
128 * 256

# %%
f

# %%
len(f)
# Out:
# 129
